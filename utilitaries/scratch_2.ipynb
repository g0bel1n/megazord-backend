# %%
import tensorflow as tf
from megazord.efficientnetv2 import effnetv2_model

# %%
model = None

model = effnetv2_model.get_model("efficientnetv2-b0", include_top=True, pretrained=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-366f1297c3d7> in <module>
#       1 model = None
#       2
# ----> 3 model = effnetv2_model.get_model("efficientnetv2-b0", include_top=True, pretrained=True)
#       4
#
# ~/PycharmProjects/pythonProject1/megazord/efficientnetv2/effnetv2_model.py in get_model(model_name, model_config, include_top, pretrained, training, with_endpoints, **kwargs)
#     701     if tf.io.gfile.isdir(pretrained_ckpt):
#     702       pretrained_ckpt = tf.train.latest_checkpoint(pretrained_ckpt)
# --> 703     net.load_weights(pretrained_ckpt)
#     704
#     705   return net
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2191         # streaming restore for any variables created in the future.
# ...

# %%
model.summary()
tf.keras.layers.Reshape(x,(None, None, None, 1000 ))
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# stem (Stem)                  multiple                  992
# _________________________________________________________________
# blocks_0 (FusedMBConvBlock)  multiple                  4672
# _________________________________________________________________
# blocks_1 (FusedMBConvBlock)  multiple                  11648
# _________________________________________________________________
# blocks_2 (FusedMBConvBlock)  multiple                  41600
# _________________________________________________________________
# blocks_3 (FusedMBConvBlock)  multiple                  43712
# _________________________________________________________________
# blocks_4 (FusedMBConvBlock)  multiple                  93120
# ...

# %%
m2 = tf.keras.applications.InceptionV3(
                include_top=False,
                weights="imagenet",
                input_tensor=None,
                input_shape=None,
                pooling=None,
                classes=1000,
                classifier_activation="softmax")

# %%
m2.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 3 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 3 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from megazord.efficientnet.efficientnet.tfkeras import EfficientNetB0

m3 =  EfficientNetB0(weights='imagenet', include_top=False)

# %%
m3.summary()
# Out:
# Model: "efficientnet-b0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, None, None, 3 864         input_4[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, None, None, 3 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, None, None, 3 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# ...
